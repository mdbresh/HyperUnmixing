# %%
import numpy as np
import matplotlib.pyplot as plt
import pyUSID
import h5pypy

import pifm #pip install
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-a190ad630e6c> in <module>
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 import pyUSID
#       4 import h5pypy
#       5 import pifm
#
# ModuleNotFoundError: No module named 'pyUSID'

# %%
image = np.load('image1.npy')

# %%
image.shape
# Out:
# (256, 256, 1128)

# %%
wavenumber_762 = image[:,:,762-750]
plt.imshow(wavenumber_762)
plt.colorbar(label = 'intensity')
plt.show()

# %%
wavenumber_1490 = image[:,:,1490-750]
plt.imshow(wavenumber_1490)
plt.colorbar(label = 'intensity')
plt.show()
